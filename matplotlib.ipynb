# %% [markdown]
# <a href="https://colab.research.google.com/github/Fathima33/visualization_matplot/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/csv files/M2_T2_V1Movies.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#                                              Title  Year      Genre  Duration  \
# 0                                      What Is It?  2005      Drama        72
# 1                                          Glitter  2001      Drama       104
# 2                            The Attic Expeditions  2001     Comedy       100
# 3                                  Men in Black II  2002     Action        88
# 4     Star Wars: Episode II - Attack of the Clones  2002     Action       142
# ...                                            ...   ...        ...       ...
# 5270                                     Bloodline  2018      Crime        97
# 5271                           The Princess Switch  2018     Comedy       101
# 5272                       You Might Be the Killer  2018     Comedy        92
# 5273                                The Final Wish  2018     Horror        95
# 5274                                  Shrek Retold  2018  Animation        90
#
# ...

# %%
df1=df.Year.value_counts().to_frame()

# %%
df1
# Out:
#       Year
# 2014   393
# 2015   388
# 2017   386
# 2013   382
# 2016   375
# 2012   370
# 2018   356
# 2011   328
# 2009   327
# 2006   292
# 2007   284
# 2010   282
# 2008   260
# 2005   210
# 2002   186
# 2001   167
# 2004   150
# 2003   139

# %% [markdown]
# LINE CHART: it is used in analyzing trend over some period of time

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
plt.plot(df1.index,df1.values,color="green")
plt.xticks(df1.index, df1.index.astype(int))
plt.xticks(rotation="vertical")
# Out:
# (array([2014, 2015, 2017, 2013, 2016, 2012, 2018, 2011, 2009, 2006, 2007,
#         2010, 2008, 2005, 2002, 2001, 2004, 2003]),
#  [Text(2014, 0, '2014'),
#   Text(2015, 0, '2015'),
#   Text(2017, 0, '2017'),
#   Text(2013, 0, '2013'),
#   Text(2016, 0, '2016'),
#   Text(2012, 0, '2012'),
#   Text(2018, 0, '2018'),
#   Text(2011, 0, '2011'),
#   Text(2009, 0, '2009'),
#   Text(2006, 0, '2006'),
#   Text(2007, 0, '2007'),
#   Text(2010, 0, '2010'),
#   Text(2008, 0, '2008'),
#   Text(2005, 0, '2005'),
#   Text(2002, 0, '2002'),
#   Text(2001, 0, '2001'),
#   Text(2004, 0, '2004'),
#   Text(2003, 0, '2003')])
